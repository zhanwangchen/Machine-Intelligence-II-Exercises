# %% [markdown]
# # Exercise Sheet 11:Density Estimation
# Machine Intelligence 2<br>
# SS 2017, Obermayer/Augustin/Guo<br>
# due: **2017-07-18**<br>
# Group: Outlaws (Muhammed Cengizhan Özmen, Zhanwang Chen, Sedat Koca, Huajun Li)

# %%
 # %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import misc
import skimage

# %%
img = np.invert(misc.imread ('testimg.jpg'))
plt.figure()
plt.imshow(img, cmap='binary')
plt.show()
vector = np.reshape(img,177500)
# Normalization of the data
def MaxMinNormalization(x,Max,Min): 
    x = (x - Min)/(Max - Min)
    return x 
vector_normalized= MaxMinNormalization(vector,np.max(vector),np.min(vector))
#plot the original database

x = np.linspace(0,10,177500)
y = vector_normalized
plt.figure(figsize=(20,10))
plt.plot(x, y)
plt.title('Original Dataset without noises',fontsize=20)
plt.xlabel('x', fontsize=20)
plt.ylabel('y', fontsize=20)
plt.show()

# %%
#Adding gaussian noise to the data 
#Creating the dataset with noises
s1 = np.random.normal(0, 0.05, 177500)
s2 = np.random.normal(0, 0.1, 177500)
vector_s1 = vector_normalized + s1
vector_s2 = vector_normalized + s2

# %%
#Procedure for the original dataset
